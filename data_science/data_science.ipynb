# %%
# A good practice is to put required external packages in the first cell of the file
# %pip install -q nltk matplotlib pandas gensim wordcloud openpyxl
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# Note: you may need to restart the kernel to use updated packages.

# %%
# Followed by a list of imports in the next cell
import pandas as pd
import matplotlib as plt    # Conventional short names for packages
import nltk
import gensim

# nltk also requires downloading additional modules for functional tokenizer
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/mike-pech/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/mike-
# [nltk_data]     pech/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# #### Load your dataset into a DataFrame

# %%
data = pd.read_excel("./data/Coffee Shop Sales.xlsx")

# %%
data.head()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       2023-01-01         07:06:11                2
# 1               2       2023-01-01         07:08:56                2
# 2               3       2023-01-01         07:14:04                2
# 3               4       2023-01-01         07:20:24                1
# 4               5       2023-01-01         07:22:41                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32         3.0              Coffee
# 1         5  Lower Manhattan          57         3.1                 Tea
# 2         5  Lower Manhattan          59         4.5  Drinking Chocolate
# 3         5  Lower Manhattan          22         2.0              Coffee
# 4         5  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  datetime64[ns]
#  2   transaction_time  149116 non-null  object
#  3   transaction_qty   149116 non-null  int64
#  4   store_id          149116 non-null  int64
#  5   store_location    149116 non-null  object
#  6   product_id        149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   product_category  149116 non-null  object
#  9   product_type      149116 non-null  object
#  10  product_detail    149116 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 12.5+ MB

# %%
data[100:150]
# Out:
#      transaction_id transaction_date transaction_time  transaction_qty  \
# 100             101       2023-01-01         10:51:17                1
# 101             102       2023-01-01         10:52:44                2
# 102             103       2023-01-01         10:52:44                1
# 103             104       2023-01-01         10:56:14                1
# 104             105       2023-01-01         10:56:14                1
# 105             106       2023-01-01         11:01:48                1
# 106             107       2023-01-01         11:01:58                1
# 107             108       2023-01-01         11:01:58                1
# 108             109       2023-01-01         11:03:25                2
# 109             110       2023-01-01         11:03:25                1
# 110             111       2023-01-01         11:04:32                2
# 111             112       2023-01-01         11:08:11                1
# ...

# %% [markdown]
# #### Display the selected column

# %%
data["product_category"]
# Out:
# 0                     Coffee
# 1                        Tea
# 2         Drinking Chocolate
# 3                     Coffee
# 4                        Tea
#                  ...
# 149111                   Tea
# 149112                   Tea
# 149113                   Tea
# 149114                Coffee
# 149115              Flavours
# Name: product_category, Length: 149116, dtype: object

# %% [markdown]
# #### Display several selected columns
#
# Note the syntax — we pass in a **list** of desired column names as an index

# %%
data[["product_category", "store_id", "store_location"]]
# Out:
#           product_category  store_id   store_location
# 0                   Coffee         5  Lower Manhattan
# 1                      Tea         5  Lower Manhattan
# 2       Drinking Chocolate         5  Lower Manhattan
# 3                   Coffee         5  Lower Manhattan
# 4                      Tea         5  Lower Manhattan
# ...                    ...       ...              ...
# 149111                 Tea         8   Hell's Kitchen
# 149112                 Tea         8   Hell's Kitchen
# 149113                 Tea         8   Hell's Kitchen
# 149114              Coffee         8   Hell's Kitchen
# 149115            Flavours         8   Hell's Kitchen
#
# [149116 rows x 3 columns]

# %% [markdown]
# #### With selection you are able to create new DataFrames from existing ones
